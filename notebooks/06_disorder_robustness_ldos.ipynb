# %% [markdown]
# # 06 — Disorder: separating topological protection from gap-robustness
#
# Two disorder classes are run, each with a **trivial-phase control**:
#
# * **bond** (random hoppings): *preserves* chiral symmetry — the zero mode stays
#   pinned at `Re(E)=0` (topological protection).
# * **on-site** (random energies): *breaks* chiral symmetry — the zero mode drifts.
#
# The trivial controls (no edge mode) stay at `E≈1`, confirming the enhancement is
# topological in origin. This is the corrected, control-equipped replacement for
# the v1 on-site-only study.

# %%
import sys; sys.path.insert(0, "../src")
import numpy as np, matplotlib.pyplot as plt
import nh_topo as nt
from nh_topo import plotting as P
cfg = nt.load_all(config_dir="../config"); p = nt.get_physics_params(cfg)
from pathlib import Path
def figdir(key): return Path("..") / nt.get_figure_dir(cfg, key)
print(f"t1={p['t1']}, t2={p['t2']}, gamma={p['gamma']}, N={p['N']}, "
      f"|nu|={nt.topological_invariant(p['t1'], p['t2'])}")
# Out:
# t1=0.8, t2=1.2, gamma=0.3, N=20, |nu|=1

# %%
gap = np.linspace(-p["gap_hw"], p["gap_hw"], 121); bulk = nt.central_bulk_site(p["N"])
study = nt.run_disorder_study(p["N"], p["t1"], p["t2"], p["gamma"], p["edge_site"], bulk,
                              gap, p["eta"], p["W_vals"], p["disorder_classes"],
                              p["n_real"], p["seed"], trivial_t2=p["trivial_t2_over_t1"]*p["t1"])
for W in p["W_vals"]:
    b, o = study["topological"]["bond"][W], study["topological"]["on_site"][W]
    print(f"W={W:.1f}: bond |ReE|={b['disp']['mean']:.4f} E={b['enh']['mean']:.2f}"
          f" | onsite |ReE|={o['disp']['mean']:.4f} E={o['enh']['mean']:.2f}"
          f" | trivial E={study['trivial']['on_site'][W]['enh']['mean']:.2f}")
fig, _ = P.plot_disorder_protection(p["W_vals"], study)
P.save_fig(fig, figdir("06_disorder_robustness_ldos"), "01_protection"); plt.show()

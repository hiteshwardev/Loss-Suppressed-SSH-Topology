# %% [markdown]
# # Project overview — topological LDOS in a non-Hermitian SSH lattice
#
# This repository studies a **1D SSH photonic lattice with sublattice-selective
# loss** (`-i*gamma` on B sites only). The hopping is reciprocal, so the
# Hamiltonian is **complex-symmetric** (`H = H^T`), passive (`Im(E) <= 0`), and
# free of the non-Hermitian skin effect.
#
# **What we establish (and what we do not):**
#
# * The topological edge mode produces a large **in-gap LDOS enhancement** at the
#   boundary. This is a *topological* effect (it requires `|nu|=1`; a trivial
#   control shows none) but it is fundamentally **Hermitian** — non-Hermitian loss
#   only *attenuates* it.
# * The enhancement is **protected against chiral-symmetric (bond) disorder** and
#   **not** against chiral-breaking (on-site) disorder — demonstrated with
#   trivial-phase controls (notebook 06).
# * All LDOS results are cross-validated by **three independent algorithms**
#   (notebook 08).
# * The nanophotonic mapping (notebook 04) is an explicit coupled-mode-theory
#   *schematic*, **not** an electromagnetic validation.
#
# All physics lives in `src/nh_topo/`; notebooks are thin drivers. Every figure is
# regenerated by `python scripts/generate_all.py`.

# %%
import sys; sys.path.insert(0, "../src")
import numpy as np, matplotlib.pyplot as plt
import nh_topo as nt
from nh_topo import plotting as P
cfg = nt.load_all(config_dir="../config"); p = nt.get_physics_params(cfg)
from pathlib import Path
def figdir(key): return Path("..") / nt.get_figure_dir(cfg, key)
print(f"t1={p['t1']}, t2={p['t2']}, gamma={p['gamma']}, N={p['N']}, "
      f"|nu|={nt.topological_invariant(p['t1'], p['t2'])}")
# Out:
# t1=0.8, t2=1.2, gamma=0.3, N=20, |nu|=1

# %%
H = nt.build_ssh(p["N"], p["t1"], p["t2"], p["gamma"])
props = nt.verify_properties(H)
print("Hamiltonian properties:", props)
assert props["is_symmetric"] and props["all_passive"] and not props["is_hermitian"]
print("gamma_EP = 2|t2-t1| =", nt.exceptional_point_threshold(p["t1"], p["t2"]),
      "(operating gamma =", p["gamma"], "-> unbroken)")
print("analytic edge weight 1-(t1/t2)^2 =",
      round(nt.analytic_edge_weight(p["t1"], p["t2"]), 4))
# Out:
# Hamiltonian properties: {'is_symmetric': True, 'all_passive': True, 'is_hermitian': False, 'dim': 40}
# gamma_EP = 2|t2-t1| = 0.7999999999999998 (operating gamma = 0.3 -> unbroken)
# analytic edge weight 1-(t1/t2)^2 = 0.5556

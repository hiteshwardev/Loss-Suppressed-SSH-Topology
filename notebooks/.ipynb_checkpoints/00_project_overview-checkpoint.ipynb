# %% [markdown]
# # Topology-Driven Non-Hermitian Nanophotonics — Project Overview
#
# This notebook loads the project configuration, verifies the environment, and
# documents the package structure. All physics is in `src/nh_topo/`.

# %%
import sys
sys.path.insert(0, "..")   # find src/nh_topo from notebooks/

import numpy as np
import matplotlib.pyplot as plt
import nh_topo as nt
from nh_topo.config import load_all, get_physics_params, get_figure_dir
from pathlib import Path

cfg = load_all(config_dir="../config")
p   = get_physics_params(cfg)

# Quick confirmation
print(f"t1={p['t1']}, t2={p['t2']}, gamma={p['gamma']}, N={p['N']}")
print(f"Topological: t2/t1 = {p['t2']/p['t1']:.2f} > 1 → |nu|={nt.topological_invariant(p['t1'], p['t2'])}")

# Verify all physical properties of the Hamiltonian
H = nt.build_ssh(p['N'], p['t1'], p['t2'], p['gamma'])
props = nt.verify_properties(H)
print("\nHamiltonian properties:")
for k, v in props.items():
    print(f"  {k}: {v}")
assert props["is_symmetric"],  "H must be complex-symmetric"
assert props["all_passive"],   "H must be passive (all Im(E) <= 0)"
assert not props["is_hermitian"], "H is expected to be non-Hermitian"
print("\nAll property checks passed.")
# Out:
# t1=0.8, t2=1.2, gamma=0.3, N=20
# Topological: t2/t1 = 1.50 > 1 → |nu|=1
#
# Hamiltonian properties:
#   is_symmetric: True
#   all_passive: True
#   is_hermitian: False
#   dim: 40
#
# All property checks passed.

# %% [markdown]
# ## Package structure
#
# ```
# src/nh_topo/
# ├── hamiltonian.py    build_ssh, build_ssh_pbc, bloch_hamiltonian
# ├── topology.py       winding_number, compute_bloch_bands, qk_trajectory
# ├── ldos.py           ldos_at, ldos_spectrum, enhancement_factor, ldos_eigdecomp
# ├── spectrum.py       diagonalize, biorthogonal_density, find_edge_modes
# ├── disorder.py       run_disorder_sweep
# ├── nanophotonics.py  build_resonator_chain, extract_ssh_couplings
# ├── sweeps.py         enhancement_map, finite_size_convergence
# ├── plotting.py       all figure functions (data in, fig/axes out)
# └── config.py         load_all, get_physics_params
# ```

# %% [markdown]
# # 05 — Edge-enhanced LDOS
#
# The edge LDOS shows a sharp in-gap peak from the protected mode; the bulk is
# gapped. The integrated edge/bulk ratio is reported **with its `eta`-dependence**
# made explicit (the bulk in-gap LDOS vanishes as `eta->0`, so the ratio is *not*
# a universal number). The independent semi-infinite (Sancho–Rubio) edge LDOS is
# overlaid and is indistinguishable from the finite-chain edge.

# %%
import sys; sys.path.insert(0, "../src")
import numpy as np, matplotlib.pyplot as plt
import nh_topo as nt
from nh_topo import plotting as P
cfg = nt.load_all(config_dir="../config"); p = nt.get_physics_params(cfg)
from pathlib import Path
def figdir(key): return Path("..") / nt.get_figure_dir(cfg, key)
print(f"t1={p['t1']}, t2={p['t2']}, gamma={p['gamma']}, N={p['N']}, "
      f"|nu|={nt.topological_invariant(p['t1'], p['t2'])}")
# Out:
# t1=0.8, t2=1.2, gamma=0.3, N=20, |nu|=1

# %%
H = nt.build_ssh(p["N"], p["t1"], p["t2"], p["gamma"])
om = np.linspace(p["om_min"], p["om_max"], p["n_omega"])
edge, bulk = p["edge_site"], nt.central_bulk_site(p["N"])
rho_e = nt.ldos_spectrum(H, edge, om, p["eta"]); rho_b = nt.ldos_spectrum(H, bulk, om, p["eta"])
rho_s = nt.surface_ldos_spectrum(om, p["t1"], p["t2"], p["gamma"], p["eta"], 0)
gap = np.linspace(-p["gap_hw"], p["gap_hw"], 121)
E = nt.enhancement_factor(H, edge, bulk, gap, p["eta"])
print(f"enhancement at eta={p['eta']}: {E:.2f}x   (edge weight W0={nt.edge_mode_spectral_weight(H, edge):.4f})")
assert nt.ldos_nonnegativity_min(H, om, p["eta"]) >= -1e-12
fig, _ = P.plot_ldos(om, rho_e, rho_b, rho_s, p["gap_hw"], E, p["eta"], edge, bulk)
P.save_fig(fig, figdir("05_emitters_ldos_nanophotonics"), "01_ldos_spectra"); plt.show()

es = nt.enhancement_vs_eta(H, edge, bulk, p["gap_hw"], np.geomspace(0.01, 0.3, 16))
print("eta-scaling of E:", dict(zip(np.round(es["etas"], 3), np.round(es["enhancement"], 1))))
fig, _ = P.plot_eta_scaling(es["etas"], es["enhancement"], p["eta"])
P.save_fig(fig, figdir("05_emitters_ldos_nanophotonics"), "02_eta_scaling"); plt.show()

fig, _ = P.plot_ldos_spatial(nt.ldos_spatial_map(H, 0.0, p["eta"]), p["N"], edge, bulk)
P.save_fig(fig, figdir("05_emitters_ldos_nanophotonics"), "03_ldos_spatial"); plt.show()
# Out:
# enhancement at eta=0.05: 11.25x   (edge weight W0=0.5556)
# eta-scaling of E: {np.float64(0.01): np.float64(14.4), np.float64(0.013): np.float64(14.2), np.float64(0.016): np.float64(13.9), np.float64(0.02): np.float64(13.6), np.float64(0.025): np.float64(13.1), np.float64(0.031): np.float64(12.6), np.float64(0.039): np.float64(12.0), np.float64(0.049): np.float64(11.3), np.float64(0.061): np.float64(10.5), np.float64(0.077): np.float64(9.6), np.float64(0.097): np.float64(8.6), np.float64(0.121): np.float64(7.5), np.float64(0.152): np.float64(6.5), np.float64(0.191): np.float64(5.5), np.float64(0.239): np.float64(4.6), np.float64(0.3): np.float64(3.9)}
